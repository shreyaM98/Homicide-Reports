# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive

# %%
import pandas as pd

trainPath = '/content/drive/MyDrive/ML DS539/CoLab/training.csv'
df = pd.read_csv(trainPath)

# Filter the data to only a few columns bc there are way too many
# Let me know if there are any particular columns you want to examine, I just 
# picked a few that seemed most interesting/important
statsData = df[["state", "year", "no_of_crimes", "no_of_cities", "no_of_crime_solved", "avg_perp_age", "mean_vic_age", "Crime Rate", "Next_Year_Crime_Rate"]]

# %%
import seaborn as sns
sns.pairplot(statsData)
# How's this? Is there anything else I should go for regarding data stats?
# I'm never really sure what to do for stuff like this
